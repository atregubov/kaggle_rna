# %%
import numpy as np
import pandas as pd
import json
import datetime
import matplotlib.pyplot as plt
from pathlib import Path
import sys
import socket
import pickle
import datetime
import random
import pickle
from scipy import stats as st
from scipy.stats import ks_2samp
from numpy import mean

# %%
df = pd.read_csv("/home/user/hu_tamff/personal_projects/kaggle/train_data.csv")

# %%
for r in range(150,206,1):
    print(f"{r+1}: {len(df[df['sequence'].str.len() == r+1])}")
# Out:
# 151: 0
# 152: 0
# 153: 0
# 154: 0
# 155: 13038
# 156: 0
# 157: 0
# 158: 0
# 159: 0
# 160: 0
# 161: 0
# 162: 0
# 163: 0
# 164: 0
# 165: 0
# 166: 0
# 167: 0
# 168: 0
# 169: 0
# 170: 30000
# 171: 0
# 172: 0
# 173: 0
# 174: 0
# 175: 0
# 176: 0
# 177: 1568354
# 178: 0
# 179: 0
# 180: 0
# 181: 0
# 182: 0
# 183: 0
# 184: 0
# 185: 0
# 186: 0
# 187: 0
# 188: 0
# 189: 0
# 190: 0
# 191: 0
# 192: 0
# 193: 0
# 194: 0
# 195: 0
# 196: 0
# 197: 0
# 198: 0
# 199: 0
# 200: 0
# 201: 0
# 202: 0
# 203: 0
# 204: 0
# 205: 0
# 206: 4998

# %%
df_sample = df[df['sequence'].str.len() == 177]#

# %%
row = df_sample[12:102].to_dict('records')[0]
    
seq = row['sequence']
print(len(seq))
rc = 0
for idx, s in enumerate(seq): 
    reactivity_key = f"reactivity_{idx+1:04d}"
    err_key = f"reactivity_error_{idx+1:04d}"
#     if row[err_key] >= 0:
    print(f"{rc:04d}:{s}: {row[reactivity_key]}, {row[err_key]}")
    rc +=1
# Out:
# 177
# 0000:G: nan, nan
# 0001:G: nan, nan
# 0002:G: nan, nan
# 0003:A: nan, nan
# 0004:A: nan, nan
# 0005:C: nan, nan
# 0006:G: nan, nan
# 0007:A: nan, nan
# 0008:C: nan, nan
# 0009:U: nan, nan
# 0010:C: nan, nan
# 0011:G: nan, nan
# 0012:A: nan, nan
# 0013:G: nan, nan
# 0014:U: nan, nan
# 0015:A: nan, nan
# 0016:G: nan, nan
# 0017:A: nan, nan
# 0018:G: nan, nan
# 0019:U: nan, nan
# 0020:C: nan, nan
# 0021:G: nan, nan
# 0022:A: nan, nan
# 0023:A: nan, nan
# 0024:A: nan, nan
# 0025:A: nan, nan
# 0026:G: 0.623, 0.186
# 0027:C: 0.134, 0.303
# 0028:G: -0.062, 0.186
# 0029:U: 1.078, 0.297
# 0030:U: 0.386, 0.226
# 0031:U: 1.172, 0.186
# 0032:U: 1.607, 0.186
# 0033:G: 1.425, 0.275
# 0034:C: 0.962, 0.259
# 0035:C: -0.124, 0.243
# 0036:G: 0.485, 0.332
# 0037:C: 0.045, 0.303
# 0038:A: 0.283, 0.328
# 0039:A: 0.34, 0.303
# 0040:C: 0.134, 0.375
# 0041:U: 1.224, 0.186
# 0042:U: 1.146, 0.186
# 0043:C: 0.623, 0.275
# 0044:A: 1.97, 0.261
# 0045:A: 1.019, 0.415
# 0046:A: 1.019, 0.333
# ...
